# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
dataset = make_regression(n_samples=30, n_features=1, n_informative=1, bias=4)
X,y = dataset

# %%
plt.scatter(X, y)

# %%
# adding error to our data
np.random.seed(42)
X = np.random.rand(N,1)
e = np.random.rand(N,1) * 0.7
y = actual_w * X + actual_b + e
plt.scatter(X,y)
plt.xlabel('Xs')
plt.ylabel('ys')
plt.show()

# %% [markdown]
# # starting with random weight and bias

# %%
np.random.seed(42)
w = np.random.randn(1)
b = np.random.randn(1)
w, b
# Out:
# (array([0.49671415]), array([-0.1382643]))

# %%
y_pred = w * X + b

# %%
fig, ax = plt.subplots()
actual = ax.scatter(X, y)
predicted = ax.scatter(X, y_pred)
ax.legend((actual, predicted), ('Actual', 'Predicted'))
plt.show()

# %%
def mean_squared_error(predicted, actual):
    error = (predicted - actual) ** 2
    return error.mean()

# def gradient_descent(w, b, loss):
#     """
#     dl_dw = dl
    
#     """

# %%
np.random.seed(42)
w = np.random.randn(1)
b = np.random.randn(1)

EPOCHS = 150
lr = 0.1

losses = []
ws, bs = [], []

for epoch in range(EPOCHS):

    ws.append(w[0])
    bs.append(b[0])
    
    y_pred = w * X + b
    delta = y_pred - y
    loss = (delta ** 2).mean()
    
    # now we have to update w and b according to our loss
    w_grad =  2/N*(delta * X).sum() # dl_dw
    b_grad = (2 * delta).mean() # dl_db

    losses.append(loss)
    

    # w_grad = (2 *((w * X + b) - y) * X).mean()
    # b_grad = (2 *((w * X + b) - y)).mean()

    w -= lr * w_grad
    b -= lr * b_grad
    
    
w, b
# Out:
# (array([3.11342218]), array([1.52469255]))

# %%
plt.plot(np.arange(EPOCHS), losses)

# %%
plt.plot(ws, losses)
plt.plot(bs, losses)

# %%
new_pred = w*X+b

# %%
plt.scatter(X, y)
plt.scatter(X, new_pred)

# %%
#testing with sklearn
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([[3.36896607]]), array([1.40495411]))

# %%
lr_pred = model.predict(X)
